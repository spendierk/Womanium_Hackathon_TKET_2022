# %% [markdown]
# # Access to Quantinuum and IonQ Backends
#
# You can get access to [Quantinuum](https://www.quantinuum.com/) and [IonQ](https://ionq.com/) simulators, emulators, and quantum machines through Microsoft Azure. When creating your workspace, first-time users automatically get free 500 (USD) Azure Quantum Credits for use with each participating quantum hardware provider. If you have consumed all the credits and need more, you can apply to the [Azure Quantum Credits program](https://microsoft.qualtrics.com/jfe/form/SV_3fl9dfFrkC3g0aG?aq_source=organic). For this Hackathon, we will use the simulators and emulators that do not use Azure Quantum Credits and hence are entirely free.
#
# ## Apply for Azure Quantum Credit Free Trial
#
# If you don’t have an Azure subscription, you can [create a free Azure account](https://azure.microsoft.com/en-us/free/). If you are a student and have a university email, check out the free Azure accounts [for students](https://azure.microsoft.com/en-us/free/students/). With Azure, you can create, deploy, and manage applications across multiple clouds, on-premises, and at the edge. You will get 200 (USD) Azure credit to use in other Azure services. For information regarding the application process to the Azure Quantum Credits Program see [here](https://docs.microsoft.com/en-us/azure/quantum/azure-quantum-credits?tabs=tabid-portal). Read over the details carefully
#
# Notice that Azure credits are not the same as Azure Quantum Credits. When you create a new Azure account, you get 200 (USD) of free Azure Credits to use in your first 30 days on Microsoft services. You can only use general-purpose Azure Credits with the Microsoft providers. 3rd-party providers (providers that Microsoft doesn't own) aren't eligible. Azure Quantum Credits can be used to run programs on quantum hardware. First-time users automatically get free 500 (USD) Azure Quantum Credits on top of the 200 (USD) free Azure Credits for use with each participating quantum hardware provider. Once you have consumed all the credits, you will get error messages when submitting new jobs, and you can then upgrade to a new plan to keep using the selected quantum hardware providers.
#
# ### Important
# You must provide a credit or debit card during the application process. Microsoft Azure will make a temporary authorization on this card, but you won’t be charged unless you move to pay-as-you-go pricing.
#
# Although, there are no costs or charges to using your free credits, there may be some small storage costs, as the input and output of your credits jobs are stored in a storage account that you pay for. Job data is typically <1MB per job. For more details, see [Azure Blob Storage pricing](https://azure.microsoft.com/en-us/pricing/details/storage/blobs/).

# %% [markdown]
# ## Create an Azure Quantum workspace
#
# Follow the directions [here](https://docs.microsoft.com/en-us/azure/quantum/how-to-create-workspace?tabs=tabid-quick) to create an Azure Quantum workspace. Briefly:
#
# 1) Sign in to the Azure portal, using the credentials for your Azure subscription.
#
# 2) Select Create a resource and then search for Azure Quantum. You should see a tile for the Azure Quantum service on the results page.
#
# 3) Select Azure Quantum and then select Create. This opens a form to create a workspace.
#
# 4) Select a subscription to associate with the new workspace, i.e. Azure subscription 1
#
# 5) Select "Quick create"
#
# 6) Type in a Workspace name of your choice, i.e. "TKET"
#
# 7) Region, slect your region, i.e. West US (You will see that you have access to IonQ and Quantinuum) and click create. (do read the providers' terms and conditions carefully)
#
#
# Deployment of your workspace usually takes about 5 minutes to complete. Once done, you should see a message "Your deployment is complete". The status and deployment details will be updated in the portal.
#
# The important information for connecting your account to your computer is the `Resource ID` and `Location`, which you can find in the "Overview" section of your Quantum workspace.

# %% [markdown]
# ## Submitting a job through Azure Quantum
#
# To submit a simple job, or quantum program, to Quantinuum or IonQ we will need to install `pytket-qsharp`. It is an extension to `pytket` that allows `pytket` circuits to be executed on remote devices and simulators via Azure Quantum.
#
# In order to use `pytket-qsharp` you will first need to install the `dotnet SDK (6.0)` and the `iqsharp` tool. (On some Linux systems it is also necessary to modify your PATH.)
# 1) See [this page](https://dotnet.microsoft.com/en-us/download/dotnet/6.0) for instructions on installing the SDK on your operating system.
#
# 2) On Linux, ensure that the dotnet tools directory is on your path. Typically this will be ~/.dotnet/tools.
#
# 3) Open terminal and run `dotnet tool install -g Microsoft.Quantum.IQSharp`in `C:\` directory. You should get a mesaage stating that 'microsoft.quantum.iqsharp' was successfully installed.
#
# 4) Then run `dotnet iqsharp install --user` in the terminal/
#
# Alternatively, you can set up an environment with all the required packages using conda:
#
# `conda create -n qsharp-env -c quantum-engineering qsharp notebook`
#
# `conda activate qsharp-env`
#
# Now we are ready to install `pytket-qsharp`. In your jupyter notebook run:
#
# `pip install pytket-qsharp`
#
# And then prepare the Q# environment by running:
#
# `from pytket.extensions.qsharp import AzureBackend`

# %%
pip install pytket-qsharp;
# Out:
# Requirement already satisfied: pytket-qsharp in c:\users\kathrin.spendier\anaconda3\lib\site-packages (0.26.0)
# Requirement already satisfied: qsharp-core~=0.24.201332 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket-qsharp) (0.24.210930)
# Requirement already satisfied: pytket~=1.3 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket-qsharp) (1.4.3)
# Requirement already satisfied: qsharp~=0.24.201332 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket-qsharp) (0.24.210930)
# Requirement already satisfied: typing-extensions~=4.2 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (4.3.0)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: lark-parser~=0.7 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (0.12.0)
# Requirement already satisfied: graphviz~=0.14 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (0.20)
# Requirement already satisfied: numpy<2.0,>=1.21.4 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (1.21.5)
# Requirement already satisfied: jinja2~=3.0 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (3.1.2)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -iskit-terra (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
#   WARNING: No metadata found in c:\users\kathrin.spendier\anaconda3\lib\site-packages
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\kathrin.spendier\\Anaconda3\\Lib\\site-packages\\zmq\\libzmq.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\kathrin.spendier\anaconda3\lib\site-packages)
# Requirement already satisfied: scipy<2.0,>=1.7.2 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (1.7.3)
# Requirement already satisfied: networkx~=2.4 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (2.7.1)
# Requirement already satisfied: sympy~=1.6 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (1.10.1)
# Requirement already satisfied: types-pkg-resources in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from pytket~=1.3->pytket-qsharp) (0.1.3)
# Requirement already satisfied: qsharp-chemistry==0.24.210930 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from qsharp~=0.24.201332->pytket-qsharp) (0.24.210930)
# Requirement already satisfied: jupyter-client<7.0 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from qsharp-core~=0.24.201332->pytket-qsharp) (6.1.12)
# Collecting pyzmq<20.0.0
#   Using cached pyzmq-19.0.2-cp39-cp39-win_amd64.whl (695 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from jinja2~=3.0->pytket~=1.3->pytket-qsharp) (2.0.1)
# Requirement already satisfied: traitlets in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from jupyter-client<7.0->qsharp-core~=0.24.201332->pytket-qsharp) (5.1.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from jupyter-client<7.0->qsharp-core~=0.24.201332->pytket-qsharp) (4.10.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from jupyter-client<7.0->qsharp-core~=0.24.201332->pytket-qsharp) (2.8.2)
# Requirement already satisfied: tornado>=4.1 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from jupyter-client<7.0->qsharp-core~=0.24.201332->pytket-qsharp) (6.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from sympy~=1.6->pytket~=1.3->pytket-qsharp) (1.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<7.0->qsharp-core~=0.24.201332->pytket-qsharp) (302)
# Requirement already satisfied: six>=1.5 in c:\users\kathrin.spendier\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<7.0->qsharp-core~=0.24.201332->pytket-qsharp) (1.16.0)
# Installing collected packages: pyzmq
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.0
#     Uninstalling pyzmq-23.2.0:
#       Successfully uninstalled pyzmq-23.2.0
#   Rolling back uninstall of pyzmq
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\pyzmq-23.2.0.dist-info\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\~yzmq-23.2.0.dist-info
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\__init__.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\__init__.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\__init__.pyi
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\__init__.pyi
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\__pycache__\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\~_pycache__
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\_future.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\_future.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\_typing.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\_typing.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\asyncio.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\asyncio.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\auth\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\auth\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\auth\__pycache__\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\auth\~_pycache__
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\auth\asyncio.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\auth\asyncio.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\auth\base.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\auth\base.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\auth\certs.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\auth\certs.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\auth\ioloop.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\auth\ioloop.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\auth\thread.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\auth\thread.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\__init__.pyi
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\__init__.pyi
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\__pycache__\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\backend\~_pycache__
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\_poll.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\_poll.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\context.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\context.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\devices.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\devices.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\error.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\error.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\message.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\message.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\socket.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\socket.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\utils.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\__pycache__\utils.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\_cdefs.h
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\_cdefs.h
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\_poll.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\_poll.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\context.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\context.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\devices.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\devices.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\error.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\error.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\message.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\message.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\socket.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\socket.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cffi\utils.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cffi\utils.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\__init__.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\__init__.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\__pycache__\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\backend\cython\~_pycache__
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\_device.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\_device.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\_poll.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\_poll.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\_proxy_steerable.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\_proxy_steerable.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\_version.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\_version.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\checkrc.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\constant_enums.pxi
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\constant_enums.pxi
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\context.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\context.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\context.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\context.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\error.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\error.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\libzmq.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\libzmq.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\message.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\message.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\message.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\message.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\socket.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\socket.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\socket.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\socket.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\cython\utils.cp39-win_amd64.pyd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\cython\utils.cp39-win_amd64.pyd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\backend\select.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\backend\select.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\constants.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\constants.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\decorators.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\decorators.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\devices\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\~evices
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\error.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\error.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\eventloop\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\~ventloop
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\green\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\~reen
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\log\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\~og
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\py.typed
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\py.typed
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\ssh\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\~sh
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__init__.pyi
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__init__.pyi
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\attrsettr.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\attrsettr.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\context.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\context.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\frame.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\frame.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\poll.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\poll.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\socket.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\socket.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\stopwatch.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\stopwatch.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\tracker.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\tracker.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\__pycache__\version.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\__pycache__\version.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\attrsettr.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\attrsettr.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\context.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\context.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\frame.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\frame.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\poll.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\poll.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\socket.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\socket.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\stopwatch.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\stopwatch.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\tracker.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\tracker.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\sugar\version.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\sugar\version.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\__pycache__\
#    from C:\Users\kathrin.spendier\Anaconda3\Lib\site-packages\zmq\tests\~_pycache__
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\conftest.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\conftest.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_asyncio.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_asyncio.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_auth.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_auth.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_cffi_backend.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_cffi_backend.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_constants.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_constants.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_context.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_context.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_cython.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_cython.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_decorators.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_decorators.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_device.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_device.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_draft.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_draft.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_error.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_error.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_etc.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_etc.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_ext.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_ext.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_future.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_future.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_imports.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_imports.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_includes.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_includes.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_ioloop.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_ioloop.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_log.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_log.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_message.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_message.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_monitor.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_monitor.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_monqueue.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_monqueue.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_multipart.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_multipart.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_mypy.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_mypy.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_pair.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_pair.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_poll.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_poll.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_proxy_steerable.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_proxy_steerable.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_pubsub.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_pubsub.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_reqrep.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_reqrep.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_retry_eintr.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_retry_eintr.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_security.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_security.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_socket.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_socket.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_ssh.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_ssh.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_version.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_version.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_win32_shim.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_win32_shim.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_z85.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_z85.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\tests\test_zmqstream.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\tests\test_zmqstream.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__init__.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__init__.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\garbage.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\garbage.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\interop.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\interop.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\jsonapi.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\jsonapi.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\monitor.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\monitor.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\strtypes.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\strtypes.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\win32.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\win32.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\__pycache__\z85.cpython-39.pyc
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\__pycache__\z85.cpython-39.pyc
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\buffers.pxd
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\buffers.pxd
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\compiler.json
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\compiler.json
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\config.json
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\config.json
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\garbage.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\garbage.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\getpid_compat.h
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\getpid_compat.h
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\interop.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\interop.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\ipcmaxlen.h
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\ipcmaxlen.h
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\jsonapi.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\jsonapi.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\monitor.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\monitor.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\mutex.h
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\mutex.h
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\pyversion_compat.h
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\pyversion_compat.h
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\strtypes.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\strtypes.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\win32.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\win32.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\z85.py
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\z85.py
#   Moving to c:\users\kathrin.spendier\anaconda3\lib\site-packages\zmq\utils\zmq_compat.h
#    from C:\Users\kathrin.spendier\AppData\Local\Temp\pip-uninstall-8q4e_cn8\utils\zmq_compat.h

# %%
from pytket.extensions.qsharp import AzureBackend
# Out:
# Preparing Q# environment...

# %% [markdown]
# ### Accessing Quantinuum and IonQ targets
#
# Azure Quantum partners with third-party companies such as IonQ and Quantinuum to deliver solutions to quantum jobs. These company offerings are called providers. Each provider can offer multiple targets with different capabilities.
#
# Quantinuum's targets are listed in the table below:
#
# | Target name | Target ID | Number of qubits | Description |
# | --- | --- | --- | --- |
# | H1-1 API Validator | quantinuum.hqs-lt-s1-apival | 12 qubits | Quantinuum's "API validator." Use this to validate quantum programs before submitting to hardware or emulation on Quantinuum's platform. Free of cost. |
# | H1-1 Emulator | quantinuum.hqs-lt-s1-sim | 12 qubits | Quantinuum's quantum simulator for H1-1. Uses a noise model that is consistent with their H1-1 hardware offering. Not free of cost. |
# | H1-2 Emulator | quantinuum.hqs-lt-s2-sim | 12 qubits | Quantinuum's quantum simulator for H1-2. Uses a noise model that is consistent with their H1-2 hardware offering. Not free of cost. |
# | Quantinuum System Model: H1 Family | quantinuum.hqs-lt| 12 qubits | Quantinuum's H1 family of trapped-ion quantum computers. Not free of cost. |
# | Quantinuum System Model H1-1 | quantinuum.hqs-lt-s1| 12 qubits | Quantinuum's H1-1 computer. Not free of cost. |
# | Quantinuum System Model H-2 | quantinuum.hqs-lt-s2| 12 qubits | Quantinuum's H1-2 computer. Not free of cost. |
#
# To learn more about Quantinuum's targets, check out [this documentation](https://docs.microsoft.com/en-us/azure/quantum/provider-quantinuum) and [this](https://docs.microsoft.com/en-us/azure/quantum/provider-honeywell). How to estimate associated costs see [here](https://docs.microsoft.com/en-us/azure/quantum/pricing?tabs=tabid-AQcredits%2Ctabid-AQcreditsQ%2Ctabid-payasgo%2Ctabid-learndevelop&pivots=ide-computing).
#
# IonQ's targets are listed in this table:
#
# | Target name | Target ID | Number of qubits | Description |
# | --- | --- | --- | --- |
# | Quantum simulator | ionq.simulator | 29 qubits | IonQ's cloud-based idealized simulator. Free of cost. |
# | Quantum computer | ionq.qpu | 11 qubits | IonQ's trapped-ion quantum computer. This is real quantum hardware, not a simulation. Not for free |
#
# To learn more about IonQ's targets, check out [this documentation](https://docs.microsoft.com/en-us/azure/quantum/provider-ionq) and how to estimate associated costs see [here](https://docs.microsoft.com/en-us/azure/quantum/pricing?tabs=tabid-AQcredits%2Ctabid-AQcreditsQ%2Ctabid-payasgo%2Ctabid-learndevelop&pivots=ide-computing).
#
# To get access to Quantinuum's and IonQ's targets you need your Azure Quantum workspace `Resource ID` and `Loaction`.
#
# For example, to access the "ionq.simulator" use
#
# `backend_ionQ = AzureBackend("ionq.simulator",resourceId="your resource ID",
#    location="your location")`
#
# To access the Qunatinuum Syntax checker you run:
#
# `backend_Quant = AzureBackend("quantinuum.hqs-lt-s1-apival",resourceId="your resource ID",
#    location="your location")`

# %% [markdown]
# ### Example `pytket` job submission to IonQ
#
# Let's submit a circuit to IonQ's simulator, which is free. (note that commands are commented out with "#" to be inactive for compilation of this manual. Remove the "#" when you run the code below)

# %%
backend_ionQ = AzureBackend("ionq.simulator",resourceId="your resource ID",location="westus")
# Out:
# Please specify a valid resourceId, or specify a valid combination of subscription, resourceGroup, and workspace.
# ---------------------------------------------------------------------------
# AzureError                                Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pytket\extensions\qsharp\backends\azure_quantum.py:130, in AzureBackend.__init__(self, target_name, resourceId, location, storage, machine_debug)
#     129 try:
# --> 130     target_list = qsharp.azure.connect(**config.__dict__)
#     131 except qsharp.azure.AzureError as e:
#
# File ~\Anaconda3\lib\site-packages\qsharp\azure.py:110, in connect(**params)
#     109 result = qsharp.client._execute_magic(f"azure.connect", raise_on_stderr=False, **params)
# --> 110 if "error_code" in result: raise AzureError(result)
#     111 return [AzureTarget(target) for target in result]
#
# AzureError: {'error_code': 1012, 'error_name': 'WorkspaceNotFound', 'error_description': 'No Azure Quantum workspace was found that matches the specified criteria.'}
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 backend_ionQ = AzureBackend("ionq.simulator",resourceId="your resource ID",location="westus")
#
# File ~\Anaconda3\lib\site-packages\pytket\extensions\qsharp\backends\azure_quantum.py:139, in AzureBackend.__init__(self, target_name, resourceId, location, storage, machine_debug)
#     133     raise RuntimeError(
#     134         "Could not authenticate with Azure Quantum. "
#     135         "Ensure you have logged in in your environment"
#     136         " and installed the required packages."
#     137     )
#     138 elif e.error_name == "WorkspaceNotFound":
# --> 139     raise RuntimeError(
#     140         "No suitable Azure Quantum workspace found"
#     141         f" check the resourceId is correct: {config.resourceId}"
#     142     )
#     143 else:
#     144     raise e
#
# RuntimeError: No suitable Azure Quantum workspace found check the resourceId is correct: your resource ID

# %% [markdown]
# Below we generate a circuit that will produce a Bell state, assuming the qubits are all initialized in the |0> state:

# %%
from pytket import Circuit
from pytket.circuit.display import render_circuit_jupyter
circ = Circuit(2,2)
circ.H(0)
circ.CX(0, 1)

# %% [markdown]
# Suppose we want to measure this Bell state to get some actual results out, so let's append some `Measure` gates to the circuit. The `Circuit` class has the measure_all utility function, which appends `Measure` gates on every qubit. This function will automatically add the classical bits to the circuit if they are not already there. All of these results will be written to the default classical register ('c').

# %%
circ.measure_all()
render_circuit_jupyter(circ)
# Out:
# <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
# &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34;&gt;
#
#     &lt;script type=&#34;application/javascript&#34; src=&#34;https://cdn.jsdelivr.net/npm/vue@3&#34;&gt;&lt;/script&gt;
#     &lt;script type=&#34;application/javascript&#34; src=&#34;https://unpkg.com/pytket-circuit-renderer@0.1/dist/pytket-circuit-renderer.umd.js&#34;&gt;&lt;/script&gt;
#     &lt;link rel=&#34;stylesheet&#34; href=&#34;https://unpkg.com/pytket-circuit-renderer@0.1/dist/pytket-circuit-renderer.css&#34;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&#34;circuit-display-vue-container-9029ef69-85cf-47c9-bfb1-224334e65848&#34; class=&#34;pytket-circuit-display-container&#34;&gt;
#         &lt;div style=&#34;display: none&#34;&gt;
#             &lt;div id=&#34;circuit-json-to-display&#34;&gt;{&#34;bits&#34;: [[&#34;c&#34;, [0]], [&#34;c&#34;, [1]]], &#34;commands&#34;: [{&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;H&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;c&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;c&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}], &#34;implicit_permutation&#34;: [[[&#34;q&#34;, [0]], [&#34;q&#34;, [0]]], [[&#34;q&#34;, [1]], [&#34;q&#34;, [1]]]], &#34;phase&#34;: &#34;0.0&#34;, &#34;qubits&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]]}&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;circuit-display-container :circuit-element-str=&#34;&#39;#circuit-json-to-display&#39;&#34;&gt;&lt;/circuit-display-container&gt;
#     &lt;/div&gt;
#
#     &lt;script type=&#34;application/javascript&#34;&gt;
#         const { createApp } = Vue;
#         const circuitDisplayContainer = window[&#34;pytket-circuit-renderer&#34;].default;
#
#         // Init variables to be shared between circuit display instances
#         if (typeof window.pytketCircuitDisplays === &#34;undefined&#34;) {
#             window.pytketCircuitDisplays = {};
#         }
#
#         const uid = &#34;9029ef69-85cf-47c9-bfb1-224334e65848&#34;;
#
#         // Create the root Vue component
#         window.pytketCircuitDisplays[uid] = createApp({
#             delimiters: [&#39;[[#&#39;, &#39;#]]&#39;],
#             components: { circuitDisplayContainer },
#         }).mount(&#34;#circuit-display-vue-container-&#34;+uid);
#     &lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;
# "
#         width="100%" height="200px"
#         style="border: none; outline: none; resize: vertical; overflow: auto"></iframe>

# %% [markdown]
# Check if our circuit is valid to be run.

# %%
backend_ionQ.valid_circuit(circ)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 backend_ionQ.valid_circuit(circ)
#
# NameError: name 'backend_ionQ' is not defined

# %% [markdown]
# We are now good to run this circuit on the device. After submitting, we can use the handle to check the status of the job so that we know when results are ready to be retrieved. The `circuit_status` method works for all backends and returns a `CircuitStatus` object. If we just run `get_result` straight away, the backend will wait for results to complete, blocking any other code from running.

# %%
quantum_handle = backend_ionQ.process_circuit(circ, n_shots=100)
print(backend_ionQ.circuit_status(quantum_handle))
quantum_counts = backend_ionQ.get_result(quantum_handle).get_counts()
print(quantum_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 quantum_handle = backend_ionQ.process_circuit(circ, n_shots=100)
#       2 print(backend_ionQ.circuit_status(quantum_handle))
#       3 quantum_counts = backend_ionQ.get_result(quantum_handle).get_counts()
#
# NameError: name 'backend_ionQ' is not defined

# %% [markdown]
# ### Example `pytket` job submission to Quantinuum
#
# Let's submit a circuit to Quantinuum's emulator, which is for a charge. (note that commands are commented out with "#" to be inactive for compilation of this manual. Remove the "#" when you run the code below)

# %%
#backend_Q = AzureBackend("quantinuum.hqs-lt-s1-sim",resourceId="your resource ID",location="westus")

# %%
#backend_Q.valid_circuit(circ)

# %%
#quantum_handle = backend_Q.process_circuit(circ, n_shots=10)
#print(backend_Q.circuit_status(quantum_handle))
#quantum_counts = backend_Q.get_result(quantum_handle).get_counts()
#print(quantum_counts)

# %% [markdown]
# Quantinuum's quotas are tracked based on the QPU usage credit unit, H1 Quantum Credit (HQC) for jobs submitted to System Model H1 quantum computer series, and eHQC for the emulators. The estimated cost for running this Bell state 10 times on a H1 emulator is 5 eHQC. (Note HQC and eHQC are computed using the same formula). Your free Azure Quantum account gives you 160 eHQC. We now have used 5 of the 160 eHQC.
